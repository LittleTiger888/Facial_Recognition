# %% [markdown]
# # Exploratory Data Analysis
# 1. Distribution of Male and Female
#  - Bar Chart
#  - Pie Chart
# 2. What Distribution of size of all Images
#  - Histogram
#  - Box Plot
#  - Split by “Gender”
# 3. Make the decision of width & height to resize using above chart.
# 4. Remove the few images that are having very less size

# %%
# !pip install seaborn

# %%
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# computer vision library
import cv2

# glob
from glob import glob

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# extract path of male and female in crop_data folder and put them in a list
fpath = glob('crop_data/female/*.jpg')
mpath = glob('crop_data/male/*.jpg')

# %%
df_female = pd.DataFrame(fpath,columns=['filepath'])
df_female['gender'] = 'female'

df_male = pd.DataFrame(mpath,columns=['filepath'])
df_male['gender'] = 'male'

df = pd.concat((df_female,df_male),axis=0)

df.head()
# Out:
#                            filepath  gender
# 0   crop_data/female/female_882.jpg  female
# 1  crop_data/female/female_4182.jpg  female
# 2  crop_data/female/female_3664.jpg  female
# 3  crop_data/female/female_2673.jpg  female
# 4  crop_data/female/female_2896.jpg  female

# %%
df.tail()
# Out:
#                           filepath gender
# 3463   crop_data/male/male_555.jpg   male
# 3464  crop_data/male/male_1035.jpg   male
# 3465   crop_data/male/male_160.jpg   male
# 3466  crop_data/male/male_1490.jpg   male
# 3467   crop_data/male/male_534.jpg   male

# %%
df.shape
# Out:
# (7211, 2)

# %%
# it will take each image path
# then return width of the image
def get_size(path):
    img = cv2.imread(path)
    return img.shape[0]

# %%
df['dimension'] = df['filepath'].apply(get_size) # store dimension of image in this columns

# %%
df.head()
# Out:
#                            filepath  gender  dimension
# 0   crop_data/female/female_882.jpg  female        122
# 1  crop_data/female/female_4182.jpg  female        273
# 2  crop_data/female/female_3664.jpg  female         81
# 3  crop_data/female/female_2673.jpg  female        122
# 4  crop_data/female/female_2896.jpg  female        182

# %% [markdown]
# #### Exploratory Data Analysis
# 1. Distribution of Male and Female
#  - Bar Chart
#  - Pie Chart
# 2. What Distribution of size of all Images
#  - Histogram
#  - Box Plot
#  - Split by “Gender”
# 3. Make the decision of width & height to resize using above chart.
# 4. Remove the few images that are having very less size

# %%
dist_gender = df['gender'].value_counts()
dist_gender
# Out:
# gender
# female    3743
# male      3468
# Name: count, dtype: int64

# %%
fig,ax = plt.subplots(nrows=1,ncols=2)
dist_gender.plot(kind='bar',ax=ax[0])
dist_gender.plot(kind='pie',ax=ax[1],autopct='%0.0f%%')
plt.show()

# %%
# What Distribution of size of all Images
# Histogram
# Box Plot
# Split by “Gender”
plt.figure(figsize=(12,6))
plt.subplot(2,1,1)
sns.histplot(df['dimension'])
plt.subplot(2,1,2)
sns.boxplot(df['dimension'])
plt.show()

# %%
sns.catplot(data=df,x='gender',y='dimension',kind='box')

# %% [markdown]
# 1. We have almost equal distrbution of gender (numbers)
# 2. Most of the images are having dimension more than 60
# 3. Female most of the female images are HD compare to male images
#
# ---
# - **Consider the image with dimensions more than 60**
# - **Resize all the the image into 100 x 100**

# %%
df_filter = df.query('dimension > 60')
df_filter.shape
# Out:
# (6540, 3)

# %%
df_filter['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.528135
# male      0.471865
# Name: proportion, dtype: float64

# %% [markdown]
# #### Structure the image
# - 100 x 100

# %%
def structuring(path):
    try:

        # step - 1: read image
        img = cv2.imread(path) # BGR
        # step - 2: convert into grayscale
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        # step -3: resize into 100 x 100 array   

        size = gray.shape[0]
        if size >= 100:
            # cv2.INTER_AREA (SHINK)
            gray_resize = cv2.resize(gray,(100,100),cv2.INTER_AREA)
        else:
            # cv2.INTER_CUBIC (ENLARGE)
            gray_resize = cv2.resize(gray,(100,100),cv2.INTER_CUBIC)

        # step -4: Flatten Image (1x10,000)
        flatten_image = gray_resize.flatten()
        return flatten_image
    
    except:
        return None

# %%
df_filter['data'] = df_filter['filepath'].apply(structuring) # convert all images into 100 x 100
df_filter.head()
# Out:
#                            filepath  gender  dimension  \
# 0   crop_data/female/female_882.jpg  female        122
# 1  crop_data/female/female_4182.jpg  female        273
# 2  crop_data/female/female_3664.jpg  female         81
# 3  crop_data/female/female_2673.jpg  female        122
# 4  crop_data/female/female_2896.jpg  female        182
#
#                                                 data
# 0  [86, 80, 79, 81, 82, 82, 86, 96, 99, 92, 84, 8...
# 1  [20, 27, 35, 62, 7, 41, 25, 45, 52, 83, 88, 5,...
# 2  [64, 66, 64, 60, 57, 50, 40, 34, 39, 51, 49, 4...
# 3  [138, 114, 66, 54, 67, 73, 62, 62, 62, 41, 39,...
# 4  [51, 55, 55, 58, 60, 64, 66, 71, 74, 76, 81, 8...

# %%
data = df_filter['data'].apply(pd.Series)
data.columns = [f"pixel_{i}" for i in data.columns]
data.head()
# Out:
#    pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0       86       80       79       81       82       82       86       96
# 1       20       27       35       62        7       41       25       45
# 2       64       66       64       60       57       50       40       34
# 3      138      114       66       54       67       73       62       62
# 4       51       55       55       58       60       64       66       71
#
#    pixel_8  pixel_9  ...  pixel_9990  pixel_9991  pixel_9992  pixel_9993  \
# 0       99       92  ...          87          93          96         104
# 1       52       83  ...         174         167         166         168
# 2       39       51  ...          42          28          25          30
# 3       62       41  ...          23          30          55          75
# 4       74       76  ...         170         179         187         195
#
#    pixel_9994  pixel_9995  pixel_9996  pixel_9997  pixel_9998  pixel_9999
# 0         105         100         112         126         129         133
# 1         169         164         161          48          45          41
# 2          37          38          33          38          45          41
# 3          89          96          97          69          38          34
# 4         201         204         206         205         206         204
#
# [5 rows x 10000 columns]

# %% [markdown]
# #### Data Normalization

# %%
# since for 8 bit image max value is 255 
# therefore we are dividing each and every pixel with 255
data = data/255.0 
data['gender'] = df_filter['gender']
data.head()
# Out:
#     pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0  0.337255  0.313725  0.309804  0.317647  0.321569  0.321569  0.337255
# 1  0.078431  0.105882  0.137255  0.243137  0.027451  0.160784  0.098039
# 2  0.250980  0.258824  0.250980  0.235294  0.223529  0.196078  0.156863
# 3  0.541176  0.447059  0.258824  0.211765  0.262745  0.286275  0.243137
# 4  0.200000  0.215686  0.215686  0.227451  0.235294  0.250980  0.258824
#
#     pixel_7   pixel_8   pixel_9  ...  pixel_9991  pixel_9992  pixel_9993  \
# 0  0.376471  0.388235  0.360784  ...    0.364706    0.376471    0.407843
# 1  0.176471  0.203922  0.325490  ...    0.654902    0.650980    0.658824
# 2  0.133333  0.152941  0.200000  ...    0.109804    0.098039    0.117647
# 3  0.243137  0.243137  0.160784  ...    0.117647    0.215686    0.294118
# 4  0.278431  0.290196  0.298039  ...    0.701961    0.733333    0.764706
#
#    pixel_9994  pixel_9995  pixel_9996  pixel_9997  pixel_9998  pixel_9999  \
# 0    0.411765    0.392157    0.439216    0.494118    0.505882    0.521569
# 1    0.662745    0.643137    0.631373    0.188235    0.176471    0.160784
# 2    0.145098    0.149020    0.129412    0.149020    0.176471    0.160784
# 3    0.349020    0.376471    0.380392    0.270588    0.149020    0.133333
# 4    0.788235    0.800000    0.807843    0.803922    0.807843    0.800000
#
#    gender
# 0  female
# 1  female
# 2  female
# 3  female
# 4  female
#
# [5 rows x 10001 columns]

# %%
###
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
## remove the missing values
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (6540, 10001)

# %% [markdown]
# **Save the data** for future study

# %%
import pickle

# %%
pickle.dump(data,open('./data/data_images_100_100.pickle',mode='wb'))

# %% [markdown]
# ---
# ### END
