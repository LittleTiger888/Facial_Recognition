# %%
import numpy as np
import pandas as pd

# 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
# load numpy array
data = np.load('data/data_pca_50_target.npz')
data.files
# Out:
# ['arr_0', 'arr_1']

# %%
data.allow_pickle = True

# %%
X = data['arr_0'] # pca data with 50 components
y = data['arr_1'] # target or dependent variable

# %%
X.shape,y.shape
# Out:
# ((6540, 50), (6540,))

# %%
X
# Out:
# array([[ 1.57580079, -0.50402487,  0.11164958, ..., -0.75585663,
#          0.99301705,  0.1133236 ],
#        [-0.0702743 , -1.93651129,  0.65026782, ..., -1.28672628,
#          0.12173058, -0.2628243 ],
#        [-0.25288082, -0.94052767, -0.84793568, ..., -0.44701399,
#          0.09866262, -0.16176726],
#        ...,
#        [ 0.15987077,  0.27575875, -1.97267044, ...,  1.05880457,
#          0.5206037 ,  0.35181657],
#        [-1.62380426,  0.92051555, -2.85796138, ...,  0.72989619,
#          2.02006675,  0.70342068],
#        [ 0.93899253,  0.85546166, -0.96344381, ...,  1.38846891,
#         -0.86489166, -0.25963655]])

# %%
y
# Out:
# array(['female', 'female', 'female', ..., 'male', 'male', 'male'],
#       dtype=object)

# %% [markdown]
# ### split the data into train and test

# %%
x_train,x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (5232, 50) (1308, 50) (5232,) (1308,)

# %% [markdown]
# ### training machine learning model

# %%
model_svc = SVC(probability=True)

param_grid = {'C':[0.5,1,10,20,30,50],
             'kernel':['rbf','poly'],
             'gamma':[0.1,0.05,0.01,0.001,0.002,0.005],
             'coef0':[0,1]}

# %%
model_grid = GridSearchCV(model_svc,
                          param_grid=param_grid,
                          scoring='accuracy',cv=3,verbose=2)

# %%
from sklearn import set_config
set_config(display='text')

model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV] END ..............C=0.5, coef0=0, gamma=0.1, kernel=rbf; total time=   1.5s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.2s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.2s
# [CV] END .............C=0.5, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   0.9s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END .............C=0.5, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=0.5, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=0.5, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ............C=0.5, coef0=0, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ............C=0.5, coef0=0, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ...........C=0.5, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ...........C=0.5, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ...........C=0.5, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=0.5, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=0.5, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=0.5, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ...........C=0.5, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ...........C=0.5, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ...........C=0.5, coef0=0, gamma=0.002, kernel=poly; total time=   0.9s
# [CV] END ............C=0.5, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ...........C=0.5, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ...........C=0.5, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ...........C=0.5, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ..............C=0.5, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ..............C=0.5, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ..............C=0.5, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END .............C=0.5, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END .............C=0.5, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END .............C=0.5, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END .............C=0.5, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=0.5, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=0.5, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ............C=0.5, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ............C=0.5, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ............C=0.5, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=0.5, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=0.5, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=0.5, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ............C=0.5, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ............C=0.5, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ............C=0.5, coef0=1, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ............C=0.5, coef0=1, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ............C=0.5, coef0=1, gamma=0.001, kernel=rbf; total time=   1.2s
# [CV] END ...........C=0.5, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ...........C=0.5, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ...........C=0.5, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ............C=0.5, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=0.5, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=0.5, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ...........C=0.5, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ...........C=0.5, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ...........C=0.5, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ............C=0.5, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=0.5, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ...........C=0.5, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END ...........C=0.5, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END ...........C=0.5, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END ................C=1, coef0=0, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ................C=1, coef0=0, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ................C=1, coef0=0, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ...............C=1, coef0=0, gamma=0.1, kernel=poly; total time=   1.2s
# [CV] END ...............C=1, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ...............C=1, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ...............C=1, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ...............C=1, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ...............C=1, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=1, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END ...............C=1, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ...............C=1, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ...............C=1, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ..............C=1, coef0=0, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ..............C=1, coef0=0, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END .............C=1, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ..............C=1, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END .............C=1, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ................C=1, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ................C=1, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ................C=1, coef0=1, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ...............C=1, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ...............C=1, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ...............C=1, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ...............C=1, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ...............C=1, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ...............C=1, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=1, coef0=1, gamma=0.05, kernel=poly; total time=   0.9s
# [CV] END ..............C=1, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ..............C=1, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ...............C=1, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ...............C=1, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ...............C=1, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ..............C=1, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ..............C=1, coef0=1, gamma=0.01, kernel=poly; total time=   0.7s
# [CV] END ..............C=1, coef0=1, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ..............C=1, coef0=1, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ..............C=1, coef0=1, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END .............C=1, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END ..............C=1, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=1, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ..............C=1, coef0=1, gamma=0.005, kernel=rbf; total time=   0.9s
# [CV] END ..............C=1, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ..............C=1, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=1, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END .............C=1, coef0=1, gamma=0.005, kernel=poly; total time=   0.7s
# [CV] END ...............C=10, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=10, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=10, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=10, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=10, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=10, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=10, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=10, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=10, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END ..............C=10, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=10, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=10, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END ............C=10, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=10, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=10, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.002, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ............C=10, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=10, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=10, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=10, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=10, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=10, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ...............C=10, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=10, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=10, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=10, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=10, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=10, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=10, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=10, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=10, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=10, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ..............C=10, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=10, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END ..............C=10, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=1, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END ............C=10, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END ............C=10, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END ............C=10, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END .............C=10, coef0=1, gamma=0.002, kernel=rbf; total time=   0.9s
# [CV] END .............C=10, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=1, gamma=0.002, kernel=rbf; total time=   0.9s
# [CV] END ............C=10, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ............C=10, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END ............C=10, coef0=1, gamma=0.002, kernel=poly; total time=   0.7s
# [CV] END .............C=10, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END .............C=10, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=10, coef0=1, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=10, coef0=1, gamma=0.005, kernel=poly; total time=   0.8s
# [CV] END ............C=10, coef0=1, gamma=0.005, kernel=poly; total time=   0.8s
# [CV] END ...............C=20, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=20, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=20, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=20, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END .............C=20, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=20, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=20, coef0=0, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.01, kernel=poly; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=20, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=20, coef0=0, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.002, kernel=poly; total time=   0.9s
# [CV] END .............C=20, coef0=0, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=20, coef0=0, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=20, coef0=0, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ...............C=20, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=20, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=20, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=20, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=20, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=20, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=20, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=20, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=20, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=20, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ..............C=20, coef0=1, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=20, coef0=1, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=20, coef0=1, gamma=0.01, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.001, kernel=rbf; total time=   0.9s
# [CV] END .............C=20, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=1, gamma=0.001, kernel=poly; total time=   0.7s
# [CV] END ............C=20, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ............C=20, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END .............C=20, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=20, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=1, gamma=0.002, kernel=poly; total time=   0.8s
# [CV] END ............C=20, coef0=1, gamma=0.002, kernel=poly; total time=   0.8s
# [CV] END ............C=20, coef0=1, gamma=0.002, kernel=poly; total time=   0.8s
# [CV] END .............C=20, coef0=1, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=20, coef0=1, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=20, coef0=1, gamma=0.005, kernel=rbf; total time=   1.0s
# [CV] END ............C=20, coef0=1, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=1, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ............C=20, coef0=1, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ...............C=30, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=30, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=30, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=30, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=30, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=30, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=30, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END ..............C=30, coef0=0, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..............C=30, coef0=0, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=30, coef0=0, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=0, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=0, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END ............C=30, coef0=0, gamma=0.005, kernel=poly; total time=   1.0s
# [CV] END ............C=30, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=30, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ...............C=30, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=30, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=30, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=30, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=30, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=30, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=30, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=30, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=30, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=30, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END ..............C=30, coef0=1, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..............C=30, coef0=1, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END ..............C=30, coef0=1, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END ............C=30, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ............C=30, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END ............C=30, coef0=1, gamma=0.001, kernel=poly; total time=   0.8s
# [CV] END .............C=30, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END .............C=30, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=1, gamma=0.002, kernel=rbf; total time=   1.0s
# [CV] END ............C=30, coef0=1, gamma=0.002, kernel=poly; total time=   0.9s
# [CV] END ............C=30, coef0=1, gamma=0.002, kernel=poly; total time=   0.9s
# [CV] END ............C=30, coef0=1, gamma=0.002, kernel=poly; total time=   0.9s
# [CV] END .............C=30, coef0=1, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=1, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END .............C=30, coef0=1, gamma=0.005, kernel=rbf; total time=   1.1s
# [CV] END ............C=30, coef0=1, gamma=0.005, kernel=poly; total time=   1.1s
# [CV] END ............C=30, coef0=1, gamma=0.005, kernel=poly; total time=   1.1s
# [CV] END ............C=30, coef0=1, gamma=0.005, kernel=poly; total time=   1.1s
# [CV] END ...............C=50, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=50, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=50, coef0=0, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=0, gamma=0.1, kernel=poly; total time=   1.1s
# [CV] END ..............C=50, coef0=0, gamma=0.1, kernel=poly; total time=   1.0s
# [CV] END ..............C=50, coef0=0, gamma=0.1, kernel=poly; total time=   1.0s
# [CV] END ..............C=50, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=0, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=50, coef0=0, gamma=0.05, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END .............C=50, coef0=0, gamma=0.05, kernel=poly; total time=   1.1s
# [CV] END ..............C=50, coef0=0, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=0, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..............C=50, coef0=0, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=0, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ............C=50, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END ............C=50, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END ............C=50, coef0=0, gamma=0.001, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=0, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=50, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=50, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END ............C=50, coef0=0, gamma=0.002, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=0, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END .............C=50, coef0=0, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END .............C=50, coef0=0, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END ............C=50, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=50, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ............C=50, coef0=0, gamma=0.005, kernel=poly; total time=   0.9s
# [CV] END ...............C=50, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=50, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ...............C=50, coef0=1, gamma=0.1, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=50, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=50, coef0=1, gamma=0.1, kernel=poly; total time=   0.9s
# [CV] END ..............C=50, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=1, gamma=0.05, kernel=rbf; total time=   1.3s
# [CV] END .............C=50, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=50, coef0=1, gamma=0.05, kernel=poly; total time=   0.8s
# [CV] END .............C=50, coef0=1, gamma=0.05, kernel=poly; total time=   0.7s
# [CV] END ..............C=50, coef0=1, gamma=0.01, kernel=rbf; total time=   1.3s
# [CV] END ..............C=50, coef0=1, gamma=0.01, kernel=rbf; total time=   1.2s
# [CV] END ..............C=50, coef0=1, gamma=0.01, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.01, kernel=poly; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.01, kernel=poly; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.01, kernel=poly; total time=   1.0s
# [CV] END .............C=50, coef0=1, gamma=0.001, kernel=rbf; total time=   1.0s
# [CV] END .............C=50, coef0=1, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.001, kernel=rbf; total time=   1.1s
# [CV] END ............C=50, coef0=1, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=50, coef0=1, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END ............C=50, coef0=1, gamma=0.001, kernel=poly; total time=   0.9s
# [CV] END .............C=50, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.002, kernel=rbf; total time=   1.1s
# [CV] END ............C=50, coef0=1, gamma=0.002, kernel=poly; total time=   1.1s
# [CV] END ............C=50, coef0=1, gamma=0.002, kernel=poly; total time=   1.1s
# [CV] END ............C=50, coef0=1, gamma=0.002, kernel=poly; total time=   1.1s
# [CV] END .............C=50, coef0=1, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END .............C=50, coef0=1, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END .............C=50, coef0=1, gamma=0.005, kernel=rbf; total time=   1.2s
# [CV] END ............C=50, coef0=1, gamma=0.005, kernel=poly; total time=   1.3s
# [CV] END ............C=50, coef0=1, gamma=0.005, kernel=poly; total time=   1.3s
# [CV] END ............C=50, coef0=1, gamma=0.005, kernel=poly; total time=   1.2s
# GridSearchCV(cv=3, estimator=SVC(probability=True),
#              param_grid={'C': [0.5, 1, 10, 20, 30, 50], 'coef0': [0, 1],
#                          'gamma': [0.1, 0.05, 0.01, 0.001, 0.002, 0.005],
#                          'kernel': ['rbf', 'poly']},
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'C': 10, 'coef0': 0, 'gamma': 0.05, 'kernel': 'rbf'}

# %%
model_final = model_grid.best_estimator_

# %%
model_final.get_params()
# Out:
# {'C': 10,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 0.05,
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# ### Model Evaluation
# - Classification Report
#     - Precision, Recall, F1-Score
# - Kappa Score
#     - -ve (worst model)
#     - 0 to 0.5 (bad model)
#     - 0.5 to 0.7 (Good Model)
#     - 0.7 to 0.9 (Excellent Model)
#     - 0.9 to 1.0 (Perfect Model)
# - AUC
#     - Less than 0.5 (Worst Model)
#     - 0.5 to 0.6 (Bad Model)
#     - 0.6 to 0.8 (Good Model)
#     - 0.8 to 0.9 (Excellent Model)
#     - 0.9 to 1.0 (Perfect Model)

# %%
y_pred = model_final.predict(x_test) # predicted values

# %%
y_pred
# Out:
# array(['male', 'female', 'male', ..., 'male', 'male', 'male'],
#       dtype=object)

# %% [markdown]
# **Classification Report**

# %%
cr = metrics.classification_report(y_test,y_pred,output_dict=True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score      support
# female         0.913108  0.897250  0.905109   691.000000
# male           0.887122  0.904376  0.895666   617.000000
# accuracy       0.900612  0.900612  0.900612     0.900612
# macro avg      0.900115  0.900813  0.900388  1308.000000
# weighted avg   0.900850  0.900612  0.900655  1308.000000

# %% [markdown]
# **Kappa Score**

# %%
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.8007924253323055

# %% [markdown]
# **Area Under Curve (AUC)**

# %%
metrics.roc_auc_score(np.where(y_test=="male",1,0),
                      np.where(y_pred=="male",1,0))
# Out:
# 0.9008131873802325

# %% [markdown]
# #### Save Face Recognition Model

# %%
import pickle

# %%
pickle.dump(model_final,open('model/model_svm.pickle',mode='wb'))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cv_results = pd.DataFrame(model_grid.cv_results_)

# %%
param = ['param_C','param_coef0','param_gamma','param_kernel']
cv_results = cv_results[param+['mean_test_score']]
cv_results[param] = cv_results[param].astype(str)

# %%
plt.figure(figsize=(10,10))
for i, par in enumerate(param):
    plt.subplot(2,2,i+1)
    sns.kdeplot(data=cv_results,x='mean_test_score',hue=par)

# %%
model_grid.best_params_
# Out:
# {'C': 10, 'coef0': 0, 'gamma': 0.05, 'kernel': 'rbf'}
